# %%
# %sql
REFRESH TABLE avireportscomercial.notificaciones_canales;
select 
session
from avireportscomercial.notificaciones_canales
where month = 2 and year = 2024 and CANALES in ('RRSS','HTML','HALCON','ASSI','BPI','APP')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
